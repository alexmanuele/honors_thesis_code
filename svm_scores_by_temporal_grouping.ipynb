# %%
#groupings: all(done elsewhere), (14-28)done elsewhere, (14-21), (21-28), (14-35), (28-35), (21-35)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import mutual_info_classif
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC

def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

from sklearn.feature_selection import SelectKBest

# %%
def create_groupings(dates, rows, data):
    grouped = []
    for i in rows:
        for j in dates:
            if j in i:
                grouped.append(i)
    return data.loc[grouped].values

# %%
def create_dataset(sub, sup, dates):
    sub_group = create_groupings(dates, sub.index, sub)
    sup_group = create_groupings(dates, sup.index, sup)
    X = np.concatenate((sub_group, sup_group))
    y = ['sub'] * sub_group.shape[0] + ['sup'] * sup_group.shape[0]
    y = np.asarray(y)
    return X, y

# %%
#group the data

sub_all = pd.read_csv('all_subg_samples.csv', index_col=0)
sup_all = pd.read_csv('all_supg_samples.csv', index_col=0)

X_0_14, y_0_14 = create_dataset(sub_all, sup_all, ['-0','-14'])
X_14_21, y_14_21 = create_dataset(sub_all, sup_all, ['-14','-21'])
X_14_28, y_14_28 = create_dataset(sub_all, sup_all, ['-14','-21', '-28'])
X_21_28, y_21_28 = create_dataset(sub_all, sup_all, ['-21','-28'])
X_14_35, y_14_35 = create_dataset(sub_all, sup_all, ['-14', '-21', '-28', '-35'])
X_21_35, y_21_35 = create_dataset(sub_all, sup_all, ['-21', '-28', '-35'])
X_28_35, y_28_35 = create_dataset(sub_all, sup_all, ['-28','-35'])

# %%
#exhaustively search the param space
warnings.warn = warn


def run_parameter_search(X, y, dates):
    best = []    
    print('Search for {0} '.format(dates))
    for k in [None, 100,200,300,400,500,600,700,800,900,1000]:
        if k:
            X_new = SelectKBest(mutual_info_classif, k=k).fit_transform(X, y)
            desc = "{0} features".format(k)
        else:
            X_new = X
            desc = "All features"
        tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                         'C': [1, 10, 100, 1000]},
                            {'kernel': ['linear', 'poly','sigmoid'], 'C': [1, 10, 100, 1000]}]
        scores = ['accuracy']

        for score in scores:
            print("# Tuning hyper-parameters for %s" % score)
            print()

            clf = GridSearchCV(SVC(), tuned_parameters, cv=15,
                       scoring='%s' % score)
            clf.fit(X_new,y)

            print("Best parameters set found on development set: %s" % desc)
            print()
            print(clf.best_params_)
            print()
            print("Grid scores on development set:")
            print()
            means = clf.cv_results_['mean_test_score']
            best.append({'k':k, 'mean':np.max(means)})
            stds = clf.cv_results_['std_test_score']
            for mean, std, params in zip(means, stds, clf.cv_results_['params']):
                print("%0.3f (+/-%0.03f) for %r"
                      % (mean, std, params))
    print(best)

# %%
for data in [(X_0_14, y_0_14, "0-14"),
            (X_14_21, y_14_21, "14-21"),
            (X_14_28, y_14_28, "14-28"),
            (X_21_28, y_21_28, "21-28"),
            (X_14_35, y_14_35, "14-35"),
            (X_21_35, y_21_35, "21-35"),
            (X_28_35, y_28_35, "28-35")]:
    run_parameter_search(data[0], data[1], data[2])
# Out:
# Search for 0-14
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: All features
#
# {'C': 10, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.600 (+/-0.153) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.153) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.153) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.153) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.153) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.153) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.153) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.153) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.153) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.600 (+/-0.153) for {'C': 1, 'kernel': 'sigmoid'}
# 0.617 (+/-0.180) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.600 (+/-0.153) for {'C': 10, 'kernel': 'sigmoid'}
# 0.600 (+/-0.178) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.600 (+/-0.153) for {'C': 100, 'kernel': 'sigmoid'}
# 0.600 (+/-0.153) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.600 (+/-0.153) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 100 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.600 (+/-0.122) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.122) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.122) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.122) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.122) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.600 (+/-0.122) for {'C': 1, 'kernel': 'sigmoid'}
# 0.600 (+/-0.122) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.600 (+/-0.122) for {'C': 10, 'kernel': 'sigmoid'}
# 0.633 (+/-0.155) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.600 (+/-0.122) for {'C': 100, 'kernel': 'sigmoid'}
# 0.650 (+/-0.153) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.600 (+/-0.122) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 200 features
#
# {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.633 (+/-0.180) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.122) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.633 (+/-0.180) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.122) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.633 (+/-0.180) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.122) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.633 (+/-0.180) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.122) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'sigmoid'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'sigmoid'}
# 0.617 (+/-0.125) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 100, 'kernel': 'sigmoid'}
# 0.617 (+/-0.155) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 300 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'sigmoid'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'sigmoid'}
# 0.667 (+/-0.175) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 100, 'kernel': 'sigmoid'}
# 0.650 (+/-0.178) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 400 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.533 (+/-0.085) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'sigmoid'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'sigmoid'}
# 0.650 (+/-0.178) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.533 (+/-0.085) for {'C': 100, 'kernel': 'sigmoid'}
# 0.683 (+/-0.111) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.533 (+/-0.085) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 500 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.550 (+/-0.100) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.550 (+/-0.100) for {'C': 1, 'kernel': 'sigmoid'}
# 0.550 (+/-0.100) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.550 (+/-0.100) for {'C': 10, 'kernel': 'sigmoid'}
# 0.700 (+/-0.163) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.550 (+/-0.100) for {'C': 100, 'kernel': 'sigmoid'}
# 0.700 (+/-0.187) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.550 (+/-0.100) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 600 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.583 (+/-0.149) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 1, 'kernel': 'sigmoid'}
# 0.583 (+/-0.149) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 10, 'kernel': 'sigmoid'}
# 0.650 (+/-0.122) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 100, 'kernel': 'sigmoid'}
# 0.617 (+/-0.155) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 700 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.583 (+/-0.149) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 1, 'kernel': 'sigmoid'}
# 0.583 (+/-0.149) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 10, 'kernel': 'sigmoid'}
# 0.617 (+/-0.125) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 100, 'kernel': 'sigmoid'}
# 0.667 (+/-0.149) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 800 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.567 (+/-0.111) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.567 (+/-0.111) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.111) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.567 (+/-0.111) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.111) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.567 (+/-0.111) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.111) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.567 (+/-0.111) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.111) for {'C': 1, 'kernel': 'linear'}
# 0.550 (+/-0.100) for {'C': 1, 'kernel': 'poly'}
# 0.567 (+/-0.111) for {'C': 1, 'kernel': 'sigmoid'}
# 0.567 (+/-0.111) for {'C': 10, 'kernel': 'linear'}
# 0.567 (+/-0.111) for {'C': 10, 'kernel': 'poly'}
# 0.567 (+/-0.111) for {'C': 10, 'kernel': 'sigmoid'}
# 0.700 (+/-0.187) for {'C': 100, 'kernel': 'linear'}
# 0.567 (+/-0.111) for {'C': 100, 'kernel': 'poly'}
# 0.567 (+/-0.111) for {'C': 100, 'kernel': 'sigmoid'}
# 0.617 (+/-0.125) for {'C': 1000, 'kernel': 'linear'}
# 0.567 (+/-0.111) for {'C': 1000, 'kernel': 'poly'}
# 0.567 (+/-0.111) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 900 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.583 (+/-0.149) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 1, 'kernel': 'sigmoid'}
# 0.583 (+/-0.149) for {'C': 10, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 10, 'kernel': 'sigmoid'}
# 0.700 (+/-0.187) for {'C': 100, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 100, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 100, 'kernel': 'sigmoid'}
# 0.717 (+/-0.180) for {'C': 1000, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1000, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 1000 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.583 (+/-0.149) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1, 'kernel': 'linear'}
# 0.483 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 1, 'kernel': 'sigmoid'}
# 0.583 (+/-0.149) for {'C': 10, 'kernel': 'linear'}
# 0.483 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 10, 'kernel': 'sigmoid'}
# 0.633 (+/-0.125) for {'C': 100, 'kernel': 'linear'}
# 0.483 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 100, 'kernel': 'sigmoid'}
# 0.733 (+/-0.193) for {'C': 1000, 'kernel': 'linear'}
# 0.483 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.583 (+/-0.149) for {'C': 1000, 'kernel': 'sigmoid'}
# [{'k': None, 'mean': 0.6166666666666667}, {'k': 100, 'mean': 0.65}, {'k': 200, 'mean': 0.6333333333333333}, {'k': 300, 'mean': 0.6666666666666666}, {'k': 400, 'mean': 0.6833333333333333}, {'k': 500, 'mean': 0.7}, {'k': 600, 'mean': 0.65}, {'k': 700, 'mean': 0.6666666666666666}, {'k': 800, 'mean': 0.7}, {'k': 900, 'mean': 0.7166666666666667}, {'k': 1000, 'mean': 0.7333333333333333}]
# Search for 14-21
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: All features
#
# {'C': 10, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.717 (+/-0.180) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.717 (+/-0.180) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.717 (+/-0.180) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.717 (+/-0.180) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.717 (+/-0.180) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.717 (+/-0.180) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.717 (+/-0.180) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.717 (+/-0.180) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.717 (+/-0.180) for {'C': 1, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 1, 'kernel': 'poly'}
# 0.717 (+/-0.180) for {'C': 1, 'kernel': 'sigmoid'}
# 0.767 (+/-0.193) for {'C': 10, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 10, 'kernel': 'poly'}
# 0.717 (+/-0.180) for {'C': 10, 'kernel': 'sigmoid'}
# 0.717 (+/-0.201) for {'C': 100, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 100, 'kernel': 'poly'}
# 0.717 (+/-0.180) for {'C': 100, 'kernel': 'sigmoid'}
# 0.750 (+/-0.204) for {'C': 1000, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 1000, 'kernel': 'poly'}
# 0.717 (+/-0.180) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 100 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.617 (+/-0.180) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.180) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.180) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.180) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.180) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.180) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.180) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.180) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.180) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.617 (+/-0.180) for {'C': 1, 'kernel': 'sigmoid'}
# 0.617 (+/-0.180) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.617 (+/-0.180) for {'C': 10, 'kernel': 'sigmoid'}
# 0.883 (+/-0.155) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.617 (+/-0.180) for {'C': 100, 'kernel': 'sigmoid'}
# 0.933 (+/-0.111) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.617 (+/-0.180) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 200 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.633 (+/-0.201) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.633 (+/-0.201) for {'C': 1, 'kernel': 'sigmoid'}
# 0.633 (+/-0.201) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.633 (+/-0.201) for {'C': 10, 'kernel': 'sigmoid'}
# 0.883 (+/-0.155) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.633 (+/-0.201) for {'C': 100, 'kernel': 'sigmoid'}
# 0.900 (+/-0.122) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.633 (+/-0.201) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 300 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'sigmoid'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'sigmoid'}
# 0.850 (+/-0.178) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 100, 'kernel': 'sigmoid'}
# 0.900 (+/-0.122) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 400 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.633 (+/-0.201) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.633 (+/-0.201) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.633 (+/-0.201) for {'C': 1, 'kernel': 'sigmoid'}
# 0.633 (+/-0.201) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.633 (+/-0.201) for {'C': 10, 'kernel': 'sigmoid'}
# 0.850 (+/-0.178) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.633 (+/-0.201) for {'C': 100, 'kernel': 'sigmoid'}
# 0.917 (+/-0.149) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.633 (+/-0.201) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 500 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'sigmoid'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'sigmoid'}
# 0.800 (+/-0.187) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 100, 'kernel': 'sigmoid'}
# 0.900 (+/-0.153) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 600 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'sigmoid'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'sigmoid'}
# 0.833 (+/-0.197) for {'C': 100, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 100, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 100, 'kernel': 'sigmoid'}
# 0.817 (+/-0.193) for {'C': 1000, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1000, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 700 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'sigmoid'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'sigmoid'}
# 0.833 (+/-0.197) for {'C': 100, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 100, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 100, 'kernel': 'sigmoid'}
# 0.800 (+/-0.187) for {'C': 1000, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1000, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 800 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'sigmoid'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'sigmoid'}
# 0.833 (+/-0.197) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 100, 'kernel': 'sigmoid'}
# 0.883 (+/-0.180) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 900 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.700 (+/-0.208) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 1, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 1, 'kernel': 'poly'}
# 0.700 (+/-0.208) for {'C': 1, 'kernel': 'sigmoid'}
# 0.733 (+/-0.193) for {'C': 10, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 10, 'kernel': 'poly'}
# 0.700 (+/-0.208) for {'C': 10, 'kernel': 'sigmoid'}
# 0.833 (+/-0.175) for {'C': 100, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 100, 'kernel': 'poly'}
# 0.700 (+/-0.208) for {'C': 100, 'kernel': 'sigmoid'}
# 0.883 (+/-0.155) for {'C': 1000, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 1000, 'kernel': 'poly'}
# 0.700 (+/-0.208) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 1000 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.700 (+/-0.208) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 1, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 1, 'kernel': 'poly'}
# 0.700 (+/-0.208) for {'C': 1, 'kernel': 'sigmoid'}
# 0.733 (+/-0.193) for {'C': 10, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 10, 'kernel': 'poly'}
# 0.700 (+/-0.208) for {'C': 10, 'kernel': 'sigmoid'}
# 0.833 (+/-0.217) for {'C': 100, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 100, 'kernel': 'poly'}
# 0.700 (+/-0.208) for {'C': 100, 'kernel': 'sigmoid'}
# 0.800 (+/-0.187) for {'C': 1000, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 1000, 'kernel': 'poly'}
# 0.700 (+/-0.208) for {'C': 1000, 'kernel': 'sigmoid'}
# [{'k': None, 'mean': 0.7666666666666667}, {'k': 100, 'mean': 0.9333333333333333}, {'k': 200, 'mean': 0.9}, {'k': 300, 'mean': 0.9}, {'k': 400, 'mean': 0.9166666666666666}, {'k': 500, 'mean': 0.9}, {'k': 600, 'mean': 0.8333333333333334}, {'k': 700, 'mean': 0.8333333333333334}, {'k': 800, 'mean': 0.8833333333333333}, {'k': 900, 'mean': 0.8833333333333333}, {'k': 1000, 'mean': 0.8333333333333334}]
# Search for 14-28
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: All features
#
# {'C': 10, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.689 (+/-0.181) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 1, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 1, 'kernel': 'poly'}
# 0.689 (+/-0.181) for {'C': 1, 'kernel': 'sigmoid'}
# 0.778 (+/-0.179) for {'C': 10, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 10, 'kernel': 'poly'}
# 0.689 (+/-0.181) for {'C': 10, 'kernel': 'sigmoid'}
# 0.744 (+/-0.181) for {'C': 100, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 100, 'kernel': 'poly'}
# 0.689 (+/-0.181) for {'C': 100, 'kernel': 'sigmoid'}
# 0.733 (+/-0.200) for {'C': 1000, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 1000, 'kernel': 'poly'}
# 0.689 (+/-0.181) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 100 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.667 (+/-0.202) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.656 (+/-0.197) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.202) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.656 (+/-0.197) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.202) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.656 (+/-0.197) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.202) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.656 (+/-0.197) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.202) for {'C': 1, 'kernel': 'linear'}
# 0.511 (+/-0.074) for {'C': 1, 'kernel': 'poly'}
# 0.667 (+/-0.202) for {'C': 1, 'kernel': 'sigmoid'}
# 0.733 (+/-0.191) for {'C': 10, 'kernel': 'linear'}
# 0.511 (+/-0.074) for {'C': 10, 'kernel': 'poly'}
# 0.667 (+/-0.202) for {'C': 10, 'kernel': 'sigmoid'}
# 0.844 (+/-0.113) for {'C': 100, 'kernel': 'linear'}
# 0.511 (+/-0.074) for {'C': 100, 'kernel': 'poly'}
# 0.667 (+/-0.202) for {'C': 100, 'kernel': 'sigmoid'}
# 0.844 (+/-0.113) for {'C': 1000, 'kernel': 'linear'}
# 0.511 (+/-0.074) for {'C': 1000, 'kernel': 'poly'}
# 0.733 (+/-0.191) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 200 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.733 (+/-0.170) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.170) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.170) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.170) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.170) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.170) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.170) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.170) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.170) for {'C': 1, 'kernel': 'linear'}
# 0.522 (+/-0.083) for {'C': 1, 'kernel': 'poly'}
# 0.733 (+/-0.170) for {'C': 1, 'kernel': 'sigmoid'}
# 0.733 (+/-0.181) for {'C': 10, 'kernel': 'linear'}
# 0.522 (+/-0.083) for {'C': 10, 'kernel': 'poly'}
# 0.733 (+/-0.170) for {'C': 10, 'kernel': 'sigmoid'}
# 0.800 (+/-0.152) for {'C': 100, 'kernel': 'linear'}
# 0.522 (+/-0.083) for {'C': 100, 'kernel': 'poly'}
# 0.733 (+/-0.170) for {'C': 100, 'kernel': 'sigmoid'}
# 0.789 (+/-0.113) for {'C': 1000, 'kernel': 'linear'}
# 0.522 (+/-0.083) for {'C': 1000, 'kernel': 'poly'}
# 0.733 (+/-0.170) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 300 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.744 (+/-0.159) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.170) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.744 (+/-0.159) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.170) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.744 (+/-0.159) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.170) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.744 (+/-0.159) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.170) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.744 (+/-0.159) for {'C': 1, 'kernel': 'linear'}
# 0.522 (+/-0.083) for {'C': 1, 'kernel': 'poly'}
# 0.744 (+/-0.159) for {'C': 1, 'kernel': 'sigmoid'}
# 0.744 (+/-0.171) for {'C': 10, 'kernel': 'linear'}
# 0.522 (+/-0.083) for {'C': 10, 'kernel': 'poly'}
# 0.744 (+/-0.159) for {'C': 10, 'kernel': 'sigmoid'}
# 0.789 (+/-0.155) for {'C': 100, 'kernel': 'linear'}
# 0.522 (+/-0.083) for {'C': 100, 'kernel': 'poly'}
# 0.744 (+/-0.159) for {'C': 100, 'kernel': 'sigmoid'}
# 0.711 (+/-0.142) for {'C': 1000, 'kernel': 'linear'}
# 0.522 (+/-0.083) for {'C': 1000, 'kernel': 'poly'}
# 0.744 (+/-0.159) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 400 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.711 (+/-0.177) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.711 (+/-0.177) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.711 (+/-0.177) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.711 (+/-0.177) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.711 (+/-0.177) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.711 (+/-0.177) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.711 (+/-0.177) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.711 (+/-0.177) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.711 (+/-0.177) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.061) for {'C': 1, 'kernel': 'poly'}
# 0.711 (+/-0.177) for {'C': 1, 'kernel': 'sigmoid'}
# 0.722 (+/-0.199) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.061) for {'C': 10, 'kernel': 'poly'}
# 0.711 (+/-0.177) for {'C': 10, 'kernel': 'sigmoid'}
# 0.844 (+/-0.129) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.061) for {'C': 100, 'kernel': 'poly'}
# 0.711 (+/-0.177) for {'C': 100, 'kernel': 'sigmoid'}
# 0.778 (+/-0.131) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.061) for {'C': 1000, 'kernel': 'poly'}
# 0.711 (+/-0.177) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 500 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.733 (+/-0.191) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.191) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.191) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.191) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.191) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.191) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.191) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.191) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.191) for {'C': 1, 'kernel': 'linear'}
# 0.533 (+/-0.067) for {'C': 1, 'kernel': 'poly'}
# 0.733 (+/-0.191) for {'C': 1, 'kernel': 'sigmoid'}
# 0.733 (+/-0.119) for {'C': 10, 'kernel': 'linear'}
# 0.533 (+/-0.067) for {'C': 10, 'kernel': 'poly'}
# 0.733 (+/-0.191) for {'C': 10, 'kernel': 'sigmoid'}
# 0.778 (+/-0.157) for {'C': 100, 'kernel': 'linear'}
# 0.533 (+/-0.067) for {'C': 100, 'kernel': 'poly'}
# 0.733 (+/-0.191) for {'C': 100, 'kernel': 'sigmoid'}
# 0.744 (+/-0.171) for {'C': 1000, 'kernel': 'linear'}
# 0.533 (+/-0.067) for {'C': 1000, 'kernel': 'poly'}
# 0.733 (+/-0.191) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 600 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.733 (+/-0.147) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.744 (+/-0.134) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.147) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.744 (+/-0.134) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.147) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.744 (+/-0.134) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.147) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.744 (+/-0.134) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.147) for {'C': 1, 'kernel': 'linear'}
# 0.544 (+/-0.096) for {'C': 1, 'kernel': 'poly'}
# 0.733 (+/-0.147) for {'C': 1, 'kernel': 'sigmoid'}
# 0.711 (+/-0.142) for {'C': 10, 'kernel': 'linear'}
# 0.544 (+/-0.096) for {'C': 10, 'kernel': 'poly'}
# 0.733 (+/-0.147) for {'C': 10, 'kernel': 'sigmoid'}
# 0.800 (+/-0.125) for {'C': 100, 'kernel': 'linear'}
# 0.544 (+/-0.096) for {'C': 100, 'kernel': 'poly'}
# 0.733 (+/-0.147) for {'C': 100, 'kernel': 'sigmoid'}
# 0.822 (+/-0.096) for {'C': 1000, 'kernel': 'linear'}
# 0.544 (+/-0.096) for {'C': 1000, 'kernel': 'poly'}
# 0.733 (+/-0.147) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 700 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.678 (+/-0.142) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.689 (+/-0.147) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.678 (+/-0.142) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.689 (+/-0.147) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.678 (+/-0.142) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.689 (+/-0.147) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.678 (+/-0.142) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.689 (+/-0.147) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.678 (+/-0.142) for {'C': 1, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 1, 'kernel': 'poly'}
# 0.678 (+/-0.142) for {'C': 1, 'kernel': 'sigmoid'}
# 0.722 (+/-0.157) for {'C': 10, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 10, 'kernel': 'poly'}
# 0.678 (+/-0.142) for {'C': 10, 'kernel': 'sigmoid'}
# 0.778 (+/-0.169) for {'C': 100, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 100, 'kernel': 'poly'}
# 0.678 (+/-0.142) for {'C': 100, 'kernel': 'sigmoid'}
# 0.711 (+/-0.177) for {'C': 1000, 'kernel': 'linear'}
# 0.533 (+/-0.125) for {'C': 1000, 'kernel': 'poly'}
# 0.678 (+/-0.142) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 800 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.700 (+/-0.152) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.152) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.152) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.152) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.152) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.152) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.152) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.152) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.152) for {'C': 1, 'kernel': 'linear'}
# 0.522 (+/-0.083) for {'C': 1, 'kernel': 'poly'}
# 0.700 (+/-0.152) for {'C': 1, 'kernel': 'sigmoid'}
# 0.722 (+/-0.145) for {'C': 10, 'kernel': 'linear'}
# 0.522 (+/-0.083) for {'C': 10, 'kernel': 'poly'}
# 0.700 (+/-0.152) for {'C': 10, 'kernel': 'sigmoid'}
# 0.778 (+/-0.169) for {'C': 100, 'kernel': 'linear'}
# 0.522 (+/-0.083) for {'C': 100, 'kernel': 'poly'}
# 0.700 (+/-0.152) for {'C': 100, 'kernel': 'sigmoid'}
# 0.800 (+/-0.152) for {'C': 1000, 'kernel': 'linear'}
# 0.522 (+/-0.083) for {'C': 1000, 'kernel': 'poly'}
# 0.700 (+/-0.152) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 900 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.689 (+/-0.181) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.689 (+/-0.181) for {'C': 1, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 1, 'kernel': 'poly'}
# 0.689 (+/-0.181) for {'C': 1, 'kernel': 'sigmoid'}
# 0.722 (+/-0.179) for {'C': 10, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 10, 'kernel': 'poly'}
# 0.689 (+/-0.181) for {'C': 10, 'kernel': 'sigmoid'}
# 0.756 (+/-0.147) for {'C': 100, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 100, 'kernel': 'poly'}
# 0.689 (+/-0.181) for {'C': 100, 'kernel': 'sigmoid'}
# 0.722 (+/-0.169) for {'C': 1000, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 1000, 'kernel': 'poly'}
# 0.689 (+/-0.181) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 1000 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.678 (+/-0.177) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.678 (+/-0.177) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.678 (+/-0.177) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.678 (+/-0.177) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.678 (+/-0.177) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.678 (+/-0.177) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.678 (+/-0.177) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.678 (+/-0.177) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.678 (+/-0.177) for {'C': 1, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 1, 'kernel': 'poly'}
# 0.678 (+/-0.177) for {'C': 1, 'kernel': 'sigmoid'}
# 0.756 (+/-0.159) for {'C': 10, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 10, 'kernel': 'poly'}
# 0.678 (+/-0.177) for {'C': 10, 'kernel': 'sigmoid'}
# 0.767 (+/-0.119) for {'C': 100, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 100, 'kernel': 'poly'}
# 0.678 (+/-0.177) for {'C': 100, 'kernel': 'sigmoid'}
# 0.744 (+/-0.171) for {'C': 1000, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 1000, 'kernel': 'poly'}
# 0.678 (+/-0.177) for {'C': 1000, 'kernel': 'sigmoid'}
# [{'k': None, 'mean': 0.7777777777777778}, {'k': 100, 'mean': 0.8444444444444444}, {'k': 200, 'mean': 0.8}, {'k': 300, 'mean': 0.7888888888888889}, {'k': 400, 'mean': 0.8444444444444444}, {'k': 500, 'mean': 0.7777777777777778}, {'k': 600, 'mean': 0.8222222222222222}, {'k': 700, 'mean': 0.7777777777777778}, {'k': 800, 'mean': 0.8}, {'k': 900, 'mean': 0.7555555555555555}, {'k': 1000, 'mean': 0.7666666666666667}]
# Search for 21-28
# # Tuning hyper-parameters for accuracy
# Best parameters set found on development set: All features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.683 (+/-0.213) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.683 (+/-0.213) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.683 (+/-0.213) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.683 (+/-0.213) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.683 (+/-0.213) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.683 (+/-0.213) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.683 (+/-0.213) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.683 (+/-0.213) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.683 (+/-0.213) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.683 (+/-0.213) for {'C': 1, 'kernel': 'sigmoid'}
# 0.717 (+/-0.201) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.683 (+/-0.213) for {'C': 10, 'kernel': 'sigmoid'}
# 0.683 (+/-0.193) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.683 (+/-0.213) for {'C': 100, 'kernel': 'sigmoid'}
# 0.733 (+/-0.193) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.683 (+/-0.213) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 100 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.550 (+/-0.100) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 1, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'poly'}
# 0.550 (+/-0.100) for {'C': 1, 'kernel': 'sigmoid'}
# 0.550 (+/-0.100) for {'C': 10, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'poly'}
# 0.550 (+/-0.100) for {'C': 10, 'kernel': 'sigmoid'}
# 0.717 (+/-0.221) for {'C': 100, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 100, 'kernel': 'poly'}
# 0.550 (+/-0.100) for {'C': 100, 'kernel': 'sigmoid'}
# 0.750 (+/-0.158) for {'C': 1000, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1000, 'kernel': 'poly'}
# 0.550 (+/-0.100) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 200 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.733 (+/-0.213) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.213) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.213) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.213) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.213) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.213) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.213) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.213) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.213) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.733 (+/-0.213) for {'C': 1, 'kernel': 'sigmoid'}
# 0.650 (+/-0.220) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.733 (+/-0.213) for {'C': 10, 'kernel': 'sigmoid'}
# 0.733 (+/-0.193) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.733 (+/-0.213) for {'C': 100, 'kernel': 'sigmoid'}
# 0.783 (+/-0.180) for {'C': 1000, 'kernel': 'linear'}
# ...
# 0.533 (+/-0.139) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.139) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.139) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.139) for {'C': 1, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 1, 'kernel': 'poly'}
# 0.533 (+/-0.139) for {'C': 1, 'kernel': 'sigmoid'}
# 0.644 (+/-0.181) for {'C': 10, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 10, 'kernel': 'poly'}
# 0.533 (+/-0.139) for {'C': 10, 'kernel': 'sigmoid'}
# 0.700 (+/-0.163) for {'C': 100, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 100, 'kernel': 'poly'}
# 0.533 (+/-0.139) for {'C': 100, 'kernel': 'sigmoid'}
# 0.644 (+/-0.159) for {'C': 1000, 'kernel': 'linear'}
# 0.522 (+/-0.057) for {'C': 1000, 'kernel': 'poly'}
# 0.533 (+/-0.139) for {'C': 1000, 'kernel': 'sigmoid'}
# [{'k': None, 'mean': 0.6666666666666666}, {'k': 100, 'mean': 0.7}, {'k': 200, 'mean': 0.7222222222222222}, {'k': 300, 'mean': 0.7111111111111111}, {'k': 400, 'mean': 0.7111111111111111}, {'k': 500, 'mean': 0.7222222222222222}, {'k': 600, 'mean': 0.7444444444444445}, {'k': 700, 'mean': 0.7222222222222222}, {'k': 800, 'mean': 0.7111111111111111}, {'k': 900, 'mean': 0.7222222222222222}, {'k': 1000, 'mean': 0.7}]
# Search for 28-35
# # Tuning hyper-parameters for accuracy
# Best parameters set found on development set: All features
#
# {'C': 10, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.550 (+/-0.208) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 1, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'poly'}
# 0.550 (+/-0.208) for {'C': 1, 'kernel': 'sigmoid'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'poly'}
# 0.550 (+/-0.208) for {'C': 10, 'kernel': 'sigmoid'}
# 0.667 (+/-0.175) for {'C': 100, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 100, 'kernel': 'poly'}
# 0.550 (+/-0.208) for {'C': 100, 'kernel': 'sigmoid'}
# 0.583 (+/-0.197) for {'C': 1000, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1000, 'kernel': 'poly'}
# 0.550 (+/-0.208) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 100 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.583 (+/-0.149) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.153) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.153) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.153) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.153) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.153) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.600 (+/-0.153) for {'C': 1, 'kernel': 'sigmoid'}
# 0.600 (+/-0.153) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.600 (+/-0.153) for {'C': 10, 'kernel': 'sigmoid'}
# 0.683 (+/-0.193) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.600 (+/-0.153) for {'C': 100, 'kernel': 'sigmoid'}
# 0.650 (+/-0.220) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.600 (+/-0.153) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 200 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.533 (+/-0.085) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'sigmoid'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'sigmoid'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.533 (+/-0.085) for {'C': 100, 'kernel': 'sigmoid'}
# 0.633 (+/-0.256) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.533 (+/-0.085) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 300 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.567 (+/-0.143) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.163) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.143) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.163) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.143) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.163) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.143) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.163) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.143) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.567 (+/-0.143) for {'C': 1, 'kernel': 'sigmoid'}
# 0.567 (+/-0.143) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.567 (+/-0.143) for {'C': 10, 'kernel': 'sigmoid'}
# 0.600 (+/-0.220) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.567 (+/-0.143) for {'C': 100, 'kernel': 'sigmoid'}
# 0.700 (+/-0.187) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.567 (+/-0.143) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 400 features
#
# {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.700 (+/-0.208) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.197) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.197) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.197) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.197) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.700 (+/-0.208) for {'C': 1, 'kernel': 'sigmoid'}
# 0.700 (+/-0.208) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.700 (+/-0.208) for {'C': 10, 'kernel': 'sigmoid'}
# 0.683 (+/-0.170) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.700 (+/-0.208) for {'C': 100, 'kernel': 'sigmoid'}
# 0.667 (+/-0.217) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.700 (+/-0.208) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 500 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'sigmoid'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'sigmoid'}
# 0.617 (+/-0.180) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 100, 'kernel': 'sigmoid'}
# 0.633 (+/-0.201) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 600 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'sigmoid'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'sigmoid'}
# 0.683 (+/-0.213) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 100, 'kernel': 'sigmoid'}
# 0.633 (+/-0.239) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 700 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'sigmoid'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'sigmoid'}
# 0.617 (+/-0.201) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 100, 'kernel': 'sigmoid'}
# 0.667 (+/-0.217) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 800 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.567 (+/-0.193) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.197) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.193) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.197) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.193) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.197) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.193) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.197) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.193) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.567 (+/-0.193) for {'C': 1, 'kernel': 'sigmoid'}
# 0.567 (+/-0.193) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.567 (+/-0.193) for {'C': 10, 'kernel': 'sigmoid'}
# 0.617 (+/-0.125) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.567 (+/-0.193) for {'C': 100, 'kernel': 'sigmoid'}
# 0.633 (+/-0.155) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.567 (+/-0.193) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 900 features
#
# {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.600 (+/-0.178) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.178) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.178) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.178) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.178) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.178) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.178) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.600 (+/-0.178) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.178) for {'C': 1, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'poly'}
# 0.600 (+/-0.178) for {'C': 1, 'kernel': 'sigmoid'}
# 0.600 (+/-0.178) for {'C': 10, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'poly'}
# 0.600 (+/-0.178) for {'C': 10, 'kernel': 'sigmoid'}
# 0.600 (+/-0.200) for {'C': 100, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 100, 'kernel': 'poly'}
# 0.600 (+/-0.178) for {'C': 100, 'kernel': 'sigmoid'}
# 0.583 (+/-0.149) for {'C': 1000, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1000, 'kernel': 'poly'}
# 0.600 (+/-0.178) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 1000 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.600 (+/-0.178) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.178) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.178) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.178) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.583 (+/-0.149) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.600 (+/-0.178) for {'C': 1, 'kernel': 'linear'}
# 0.550 (+/-0.187) for {'C': 1, 'kernel': 'poly'}
# 0.600 (+/-0.178) for {'C': 1, 'kernel': 'sigmoid'}
# 0.600 (+/-0.178) for {'C': 10, 'kernel': 'linear'}
# 0.567 (+/-0.213) for {'C': 10, 'kernel': 'poly'}
# 0.600 (+/-0.178) for {'C': 10, 'kernel': 'sigmoid'}
# 0.650 (+/-0.153) for {'C': 100, 'kernel': 'linear'}
# 0.567 (+/-0.213) for {'C': 100, 'kernel': 'poly'}
# 0.600 (+/-0.178) for {'C': 100, 'kernel': 'sigmoid'}
# 0.617 (+/-0.155) for {'C': 1000, 'kernel': 'linear'}
# 0.567 (+/-0.213) for {'C': 1000, 'kernel': 'poly'}
# 0.600 (+/-0.178) for {'C': 1000, 'kernel': 'sigmoid'}
# [{'k': None, 'mean': 0.6666666666666666}, {'k': 100, 'mean': 0.6833333333333333}, {'k': 200, 'mean': 0.6333333333333333}, {'k': 300, 'mean': 0.7}, {'k': 400, 'mean': 0.7}, {'k': 500, 'mean': 0.6333333333333333}, {'k': 600, 'mean': 0.6833333333333333}, {'k': 700, 'mean': 0.6666666666666666}, {'k': 800, 'mean': 0.6333333333333333}, {'k': 900, 'mean': 0.6}, {'k': 1000, 'mean': 0.65}]

# %%
def partition(data):
    rows=data.index
    indices = []
    for p in range(11,26):
        train = []
        test = []
        sample = "{0}".format(p)
        for i in range(len(rows)):   
            if sample in rows[i]:
                test.append(i)
            else:
                train.append(i)
        indices.append((train, test))
    return indices

# %%
warnings.warn = warn


def run_partitioned_search(X, y, partition, dates):
    best = []
    print('Search for {0} '.format(dates))
    for k in [None, 100,200,300,400,500,600,700,800,900,1000]:
        if k:
            X_new = SelectKBest(mutual_info_classif, k=k).fit_transform(X.values, y)
            desc = "{0} features".format(k)
        else:
            X_new = X.values
            desc = "All features"
        tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                         'C': [1, 10, 100, 1000]},
                            {'kernel': ['linear', 'poly','sigmoid'], 'C': [1, 10, 100, 1000]}]
        scores = ['accuracy']

        for score in scores:
            print("# Tuning hyper-parameters for %s" % score)
            print()

            clf = GridSearchCV(SVC(), tuned_parameters, cv=partition,
                       scoring='%s' % score)
            clf.fit(X_new,y)

            print("Best parameters set found on development set: %s" % desc)
            print()
            print(clf.best_params_)
            print()
            print("Grid scores on development set:")
            print()
            means = clf.cv_results_['mean_test_score']
            best.append({'k':k, 'mean':np.max(means)})
            stds = clf.cv_results_['std_test_score']
            for mean, std, params in zip(means, stds, clf.cv_results_['params']):
                print("%0.3f (+/-%0.03f) for %r"
                      % (mean, std, params))
    print(best)

# %%
def create_groupings_df(dates, rows, data):
    grouped = []
    for i in rows:
        for j in dates:
            if j in i:
                grouped.append(i)
    return data.loc[grouped]

def create_dataset_df(sub, sup, dates):
    sub_group = create_groupings_df(dates, sub.index, sub)
    sup_group = create_groupings_df(dates, sup.index, sup)
    X = sub_group.append(sup_group)
    y = ['sub'] * sub_group.shape[0] + ['sup'] * sup_group.shape[0]
    y = np.asarray(y)
    return X, y

X_0_14, y_0_14 = create_dataset_df(sub_all, sup_all, ['-0','-14'])
X_14_21, y_14_21 = create_dataset_df(sub_all, sup_all, ['-14','-21'])
X_14_28, y_14_28 = create_dataset_df(sub_all, sup_all, ['-14','-21', '-28'])
X_21_28, y_21_28 = create_dataset_df(sub_all, sup_all, ['-21','-28'])
X_14_35, y_14_35 = create_dataset_df(sub_all, sup_all, ['-14', '-21', '-28', '-35'])
X_21_35, y_21_35 = create_dataset_df(sub_all, sup_all, ['-21', '-28', '-35'])
X_28_35, y_28_35 = create_dataset_df(sub_all, sup_all, ['-28','-35'])

# %%
for data in [(X_0_14, y_0_14, partition(X_0_14), "0-14"),
            (X_14_21, y_14_21,partition(X_14_21), "14-21"),
            (X_14_28, y_14_28, partition(X_14_28), "14-28"),
            (X_21_28, y_21_28, partition(X_21_28),"21-28"),
            (X_14_35, y_14_35, partition(X_14_35),"14-35"),
            (X_21_35, y_21_35, partition(X_21_35), "21-35"),
            (X_28_35, y_28_35, partition(X_28_35), "28-35")]:
    run_partitioned_search(data[0], data[1], data[2], data[3])
# Out:
# Search for 0-14
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: All features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.591 (+/-0.126) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.126) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.591 (+/-0.126) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.126) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.591 (+/-0.126) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.126) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.591 (+/-0.126) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.126) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.591 (+/-0.126) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.591 (+/-0.126) for {'C': 1, 'kernel': 'sigmoid'}
# 0.602 (+/-0.149) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.591 (+/-0.126) for {'C': 10, 'kernel': 'sigmoid'}
# 0.636 (+/-0.126) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.591 (+/-0.126) for {'C': 100, 'kernel': 'sigmoid'}
# 0.602 (+/-0.124) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.591 (+/-0.126) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 100 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.602 (+/-0.097) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.614 (+/-0.101) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.602 (+/-0.097) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.614 (+/-0.101) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.602 (+/-0.097) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.614 (+/-0.101) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.602 (+/-0.097) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.614 (+/-0.101) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.602 (+/-0.097) for {'C': 1, 'kernel': 'linear'}
# 0.545 (+/-0.060) for {'C': 1, 'kernel': 'poly'}
# 0.602 (+/-0.097) for {'C': 1, 'kernel': 'sigmoid'}
# 0.602 (+/-0.097) for {'C': 10, 'kernel': 'linear'}
# 0.545 (+/-0.060) for {'C': 10, 'kernel': 'poly'}
# 0.602 (+/-0.097) for {'C': 10, 'kernel': 'sigmoid'}
# 0.636 (+/-0.146) for {'C': 100, 'kernel': 'linear'}
# 0.545 (+/-0.060) for {'C': 100, 'kernel': 'poly'}
# 0.602 (+/-0.097) for {'C': 100, 'kernel': 'sigmoid'}
# 0.625 (+/-0.100) for {'C': 1000, 'kernel': 'linear'}
# 0.545 (+/-0.060) for {'C': 1000, 'kernel': 'poly'}
# 0.602 (+/-0.097) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 200 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.625 (+/-0.115) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.648 (+/-0.135) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.625 (+/-0.115) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.648 (+/-0.135) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.625 (+/-0.115) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.648 (+/-0.135) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.625 (+/-0.115) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.648 (+/-0.135) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.625 (+/-0.115) for {'C': 1, 'kernel': 'linear'}
# 0.523 (+/-0.030) for {'C': 1, 'kernel': 'poly'}
# 0.625 (+/-0.115) for {'C': 1, 'kernel': 'sigmoid'}
# 0.625 (+/-0.115) for {'C': 10, 'kernel': 'linear'}
# 0.511 (+/-0.015) for {'C': 10, 'kernel': 'poly'}
# 0.625 (+/-0.115) for {'C': 10, 'kernel': 'sigmoid'}
# 0.659 (+/-0.133) for {'C': 100, 'kernel': 'linear'}
# 0.511 (+/-0.015) for {'C': 100, 'kernel': 'poly'}
# 0.625 (+/-0.115) for {'C': 100, 'kernel': 'sigmoid'}
# 0.670 (+/-0.122) for {'C': 1000, 'kernel': 'linear'}
# 0.511 (+/-0.015) for {'C': 1000, 'kernel': 'poly'}
# 0.625 (+/-0.115) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 300 features
#
# {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.670 (+/-0.150) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.693 (+/-0.160) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.670 (+/-0.150) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.693 (+/-0.160) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.670 (+/-0.150) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.693 (+/-0.160) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.670 (+/-0.150) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.693 (+/-0.160) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.682 (+/-0.154) for {'C': 1, 'kernel': 'linear'}
# 0.511 (+/-0.015) for {'C': 1, 'kernel': 'poly'}
# 0.682 (+/-0.154) for {'C': 1, 'kernel': 'sigmoid'}
# 0.682 (+/-0.154) for {'C': 10, 'kernel': 'linear'}
# 0.511 (+/-0.015) for {'C': 10, 'kernel': 'poly'}
# 0.682 (+/-0.154) for {'C': 10, 'kernel': 'sigmoid'}
# 0.682 (+/-0.154) for {'C': 100, 'kernel': 'linear'}
# 0.511 (+/-0.015) for {'C': 100, 'kernel': 'poly'}
# 0.682 (+/-0.154) for {'C': 100, 'kernel': 'sigmoid'}
# 0.659 (+/-0.147) for {'C': 1000, 'kernel': 'linear'}
# 0.511 (+/-0.015) for {'C': 1000, 'kernel': 'poly'}
# 0.682 (+/-0.154) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 400 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.523 (+/-0.052) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.523 (+/-0.052) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.523 (+/-0.052) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.523 (+/-0.052) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.523 (+/-0.052) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.523 (+/-0.052) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.523 (+/-0.052) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.523 (+/-0.052) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.523 (+/-0.052) for {'C': 1, 'kernel': 'linear'}
# 0.523 (+/-0.052) for {'C': 1, 'kernel': 'poly'}
# 0.523 (+/-0.052) for {'C': 1, 'kernel': 'sigmoid'}
# 0.523 (+/-0.052) for {'C': 10, 'kernel': 'linear'}
# 0.523 (+/-0.052) for {'C': 10, 'kernel': 'poly'}
# 0.523 (+/-0.052) for {'C': 10, 'kernel': 'sigmoid'}
# 0.625 (+/-0.126) for {'C': 100, 'kernel': 'linear'}
# 0.523 (+/-0.052) for {'C': 100, 'kernel': 'poly'}
# 0.523 (+/-0.052) for {'C': 100, 'kernel': 'sigmoid'}
# 0.636 (+/-0.126) for {'C': 1000, 'kernel': 'linear'}
# 0.523 (+/-0.052) for {'C': 1000, 'kernel': 'poly'}
# 0.523 (+/-0.052) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 500 features
#
# {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.614 (+/-0.106) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.614 (+/-0.106) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.614 (+/-0.106) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.614 (+/-0.106) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.614 (+/-0.106) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.614 (+/-0.106) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.614 (+/-0.106) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.614 (+/-0.106) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.614 (+/-0.106) for {'C': 1, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 1, 'kernel': 'poly'}
# 0.614 (+/-0.106) for {'C': 1, 'kernel': 'sigmoid'}
# 0.614 (+/-0.106) for {'C': 10, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 10, 'kernel': 'poly'}
# 0.614 (+/-0.106) for {'C': 10, 'kernel': 'sigmoid'}
# 0.614 (+/-0.124) for {'C': 100, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 100, 'kernel': 'poly'}
# 0.614 (+/-0.106) for {'C': 100, 'kernel': 'sigmoid'}
# 0.602 (+/-0.124) for {'C': 1000, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 1000, 'kernel': 'poly'}
# 0.614 (+/-0.106) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 600 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.580 (+/-0.118) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.580 (+/-0.118) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.580 (+/-0.118) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.580 (+/-0.118) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.580 (+/-0.118) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.580 (+/-0.118) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.580 (+/-0.118) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.580 (+/-0.118) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.580 (+/-0.118) for {'C': 1, 'kernel': 'linear'}
# 0.534 (+/-0.103) for {'C': 1, 'kernel': 'poly'}
# 0.580 (+/-0.118) for {'C': 1, 'kernel': 'sigmoid'}
# 0.580 (+/-0.118) for {'C': 10, 'kernel': 'linear'}
# 0.534 (+/-0.103) for {'C': 10, 'kernel': 'poly'}
# 0.580 (+/-0.118) for {'C': 10, 'kernel': 'sigmoid'}
# 0.648 (+/-0.099) for {'C': 100, 'kernel': 'linear'}
# 0.534 (+/-0.103) for {'C': 100, 'kernel': 'poly'}
# 0.580 (+/-0.118) for {'C': 100, 'kernel': 'sigmoid'}
# 0.648 (+/-0.124) for {'C': 1000, 'kernel': 'linear'}
# 0.534 (+/-0.103) for {'C': 1000, 'kernel': 'poly'}
# 0.580 (+/-0.118) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 700 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.591 (+/-0.122) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.122) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.591 (+/-0.122) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.122) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.591 (+/-0.122) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.122) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.591 (+/-0.122) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.122) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.580 (+/-0.122) for {'C': 1, 'kernel': 'linear'}
# 0.523 (+/-0.052) for {'C': 1, 'kernel': 'poly'}
# 0.580 (+/-0.122) for {'C': 1, 'kernel': 'sigmoid'}
# 0.580 (+/-0.122) for {'C': 10, 'kernel': 'linear'}
# 0.523 (+/-0.052) for {'C': 10, 'kernel': 'poly'}
# 0.580 (+/-0.122) for {'C': 10, 'kernel': 'sigmoid'}
# 0.659 (+/-0.120) for {'C': 100, 'kernel': 'linear'}
# 0.523 (+/-0.052) for {'C': 100, 'kernel': 'poly'}
# 0.580 (+/-0.122) for {'C': 100, 'kernel': 'sigmoid'}
# 0.670 (+/-0.096) for {'C': 1000, 'kernel': 'linear'}
# 0.523 (+/-0.052) for {'C': 1000, 'kernel': 'poly'}
# 0.580 (+/-0.122) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 800 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.602 (+/-0.123) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.614 (+/-0.126) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.602 (+/-0.123) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.614 (+/-0.126) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.602 (+/-0.123) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.614 (+/-0.126) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.602 (+/-0.123) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.614 (+/-0.126) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.602 (+/-0.123) for {'C': 1, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 1, 'kernel': 'poly'}
# 0.602 (+/-0.123) for {'C': 1, 'kernel': 'sigmoid'}
# 0.602 (+/-0.123) for {'C': 10, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 10, 'kernel': 'poly'}
# 0.602 (+/-0.123) for {'C': 10, 'kernel': 'sigmoid'}
# 0.659 (+/-0.122) for {'C': 100, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 100, 'kernel': 'poly'}
# 0.602 (+/-0.123) for {'C': 100, 'kernel': 'sigmoid'}
# 0.716 (+/-0.161) for {'C': 1000, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 1000, 'kernel': 'poly'}
# 0.602 (+/-0.123) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 900 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.591 (+/-0.094) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.094) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.591 (+/-0.094) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.094) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.591 (+/-0.094) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.094) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.591 (+/-0.094) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.094) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.591 (+/-0.094) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.591 (+/-0.094) for {'C': 1, 'kernel': 'sigmoid'}
# 0.591 (+/-0.094) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.591 (+/-0.094) for {'C': 10, 'kernel': 'sigmoid'}
# 0.659 (+/-0.122) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.591 (+/-0.094) for {'C': 100, 'kernel': 'sigmoid'}
# 0.761 (+/-0.164) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.591 (+/-0.094) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 1000 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.602 (+/-0.099) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.094) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.602 (+/-0.099) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.094) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.602 (+/-0.099) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.094) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.602 (+/-0.099) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.591 (+/-0.094) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.602 (+/-0.099) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.602 (+/-0.099) for {'C': 1, 'kernel': 'sigmoid'}
# 0.602 (+/-0.099) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.602 (+/-0.099) for {'C': 10, 'kernel': 'sigmoid'}
# 0.670 (+/-0.122) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.602 (+/-0.099) for {'C': 100, 'kernel': 'sigmoid'}
# 0.693 (+/-0.141) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.602 (+/-0.099) for {'C': 1000, 'kernel': 'sigmoid'}
# [{'k': None, 'mean': 0.6363636363636364}, {'k': 100, 'mean': 0.6363636363636364}, {'k': 200, 'mean': 0.6704545454545454}, {'k': 300, 'mean': 0.6931818181818182}, {'k': 400, 'mean': 0.6363636363636364}, {'k': 500, 'mean': 0.6136363636363636}, {'k': 600, 'mean': 0.6477272727272727}, {'k': 700, 'mean': 0.6704545454545454}, {'k': 800, 'mean': 0.7159090909090909}, {'k': 900, 'mean': 0.7613636363636364}, {'k': 1000, 'mean': 0.6931818181818182}]
# Search for 14-21
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: All features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.690 (+/-0.145) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.690 (+/-0.145) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.690 (+/-0.145) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.690 (+/-0.145) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.690 (+/-0.145) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.690 (+/-0.145) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.690 (+/-0.145) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.690 (+/-0.145) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.690 (+/-0.145) for {'C': 1, 'kernel': 'linear'}
# 0.534 (+/-0.089) for {'C': 1, 'kernel': 'poly'}
# 0.690 (+/-0.145) for {'C': 1, 'kernel': 'sigmoid'}
# 0.716 (+/-0.160) for {'C': 10, 'kernel': 'linear'}
# 0.534 (+/-0.089) for {'C': 10, 'kernel': 'poly'}
# 0.690 (+/-0.145) for {'C': 10, 'kernel': 'sigmoid'}
# 0.759 (+/-0.106) for {'C': 100, 'kernel': 'linear'}
# 0.534 (+/-0.089) for {'C': 100, 'kernel': 'poly'}
# 0.690 (+/-0.145) for {'C': 100, 'kernel': 'sigmoid'}
# 0.784 (+/-0.146) for {'C': 1000, 'kernel': 'linear'}
# 0.534 (+/-0.089) for {'C': 1000, 'kernel': 'poly'}
# 0.690 (+/-0.145) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 100 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.655 (+/-0.190) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.190) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.190) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.190) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.190) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.190) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.190) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.190) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.190) for {'C': 1, 'kernel': 'linear'}
# 0.569 (+/-0.103) for {'C': 1, 'kernel': 'poly'}
# 0.655 (+/-0.190) for {'C': 1, 'kernel': 'sigmoid'}
# 0.655 (+/-0.190) for {'C': 10, 'kernel': 'linear'}
# 0.569 (+/-0.103) for {'C': 10, 'kernel': 'poly'}
# 0.655 (+/-0.190) for {'C': 10, 'kernel': 'sigmoid'}
# 0.828 (+/-0.138) for {'C': 100, 'kernel': 'linear'}
# 0.569 (+/-0.103) for {'C': 100, 'kernel': 'poly'}
# 0.655 (+/-0.190) for {'C': 100, 'kernel': 'sigmoid'}
# 0.862 (+/-0.098) for {'C': 1000, 'kernel': 'linear'}
# 0.569 (+/-0.103) for {'C': 1000, 'kernel': 'poly'}
# 0.655 (+/-0.190) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 200 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.655 (+/-0.180) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.180) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.180) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.180) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.180) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.180) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.180) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.180) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.180) for {'C': 1, 'kernel': 'linear'}
# 0.595 (+/-0.142) for {'C': 1, 'kernel': 'poly'}
# 0.655 (+/-0.180) for {'C': 1, 'kernel': 'sigmoid'}
# 0.655 (+/-0.180) for {'C': 10, 'kernel': 'linear'}
# 0.595 (+/-0.142) for {'C': 10, 'kernel': 'poly'}
# 0.655 (+/-0.180) for {'C': 10, 'kernel': 'sigmoid'}
# 0.828 (+/-0.127) for {'C': 100, 'kernel': 'linear'}
# 0.595 (+/-0.142) for {'C': 100, 'kernel': 'poly'}
# 0.655 (+/-0.180) for {'C': 100, 'kernel': 'sigmoid'}
# 0.853 (+/-0.109) for {'C': 1000, 'kernel': 'linear'}
# 0.595 (+/-0.142) for {'C': 1000, 'kernel': 'poly'}
# 0.655 (+/-0.180) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 300 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.621 (+/-0.159) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.621 (+/-0.159) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.621 (+/-0.159) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.621 (+/-0.159) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.621 (+/-0.159) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.621 (+/-0.159) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.621 (+/-0.159) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.621 (+/-0.159) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.621 (+/-0.159) for {'C': 1, 'kernel': 'linear'}
# 0.526 (+/-0.051) for {'C': 1, 'kernel': 'poly'}
# 0.621 (+/-0.159) for {'C': 1, 'kernel': 'sigmoid'}
# 0.621 (+/-0.159) for {'C': 10, 'kernel': 'linear'}
# 0.526 (+/-0.051) for {'C': 10, 'kernel': 'poly'}
# 0.621 (+/-0.159) for {'C': 10, 'kernel': 'sigmoid'}
# 0.836 (+/-0.104) for {'C': 100, 'kernel': 'linear'}
# 0.526 (+/-0.051) for {'C': 100, 'kernel': 'poly'}
# 0.621 (+/-0.159) for {'C': 100, 'kernel': 'sigmoid'}
# 0.879 (+/-0.118) for {'C': 1000, 'kernel': 'linear'}
# 0.526 (+/-0.051) for {'C': 1000, 'kernel': 'poly'}
# 0.621 (+/-0.159) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 400 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.638 (+/-0.172) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.629 (+/-0.159) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.638 (+/-0.172) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.629 (+/-0.159) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.638 (+/-0.172) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.629 (+/-0.159) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.638 (+/-0.172) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.629 (+/-0.159) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.638 (+/-0.172) for {'C': 1, 'kernel': 'linear'}
# 0.534 (+/-0.058) for {'C': 1, 'kernel': 'poly'}
# 0.638 (+/-0.172) for {'C': 1, 'kernel': 'sigmoid'}
# 0.638 (+/-0.172) for {'C': 10, 'kernel': 'linear'}
# 0.534 (+/-0.058) for {'C': 10, 'kernel': 'poly'}
# 0.638 (+/-0.172) for {'C': 10, 'kernel': 'sigmoid'}
# 0.759 (+/-0.158) for {'C': 100, 'kernel': 'linear'}
# 0.534 (+/-0.058) for {'C': 100, 'kernel': 'poly'}
# 0.638 (+/-0.172) for {'C': 100, 'kernel': 'sigmoid'}
# 0.853 (+/-0.143) for {'C': 1000, 'kernel': 'linear'}
# 0.534 (+/-0.058) for {'C': 1000, 'kernel': 'poly'}
# 0.638 (+/-0.172) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 500 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.655 (+/-0.160) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.160) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.160) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.160) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.160) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.160) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.160) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.160) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.160) for {'C': 1, 'kernel': 'linear'}
# 0.534 (+/-0.065) for {'C': 1, 'kernel': 'poly'}
# 0.655 (+/-0.160) for {'C': 1, 'kernel': 'sigmoid'}
# 0.655 (+/-0.160) for {'C': 10, 'kernel': 'linear'}
# 0.534 (+/-0.065) for {'C': 10, 'kernel': 'poly'}
# 0.655 (+/-0.160) for {'C': 10, 'kernel': 'sigmoid'}
# 0.767 (+/-0.138) for {'C': 100, 'kernel': 'linear'}
# 0.534 (+/-0.065) for {'C': 100, 'kernel': 'poly'}
# 0.655 (+/-0.160) for {'C': 100, 'kernel': 'sigmoid'}
# 0.836 (+/-0.130) for {'C': 1000, 'kernel': 'linear'}
# 0.534 (+/-0.065) for {'C': 1000, 'kernel': 'poly'}
# 0.655 (+/-0.160) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 600 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.655 (+/-0.160) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.664 (+/-0.162) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.160) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.664 (+/-0.162) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.160) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.664 (+/-0.162) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.160) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.664 (+/-0.162) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.160) for {'C': 1, 'kernel': 'linear'}
# 0.560 (+/-0.086) for {'C': 1, 'kernel': 'poly'}
# 0.655 (+/-0.160) for {'C': 1, 'kernel': 'sigmoid'}
# 0.655 (+/-0.160) for {'C': 10, 'kernel': 'linear'}
# 0.552 (+/-0.077) for {'C': 10, 'kernel': 'poly'}
# 0.655 (+/-0.160) for {'C': 10, 'kernel': 'sigmoid'}
# 0.767 (+/-0.143) for {'C': 100, 'kernel': 'linear'}
# 0.560 (+/-0.086) for {'C': 100, 'kernel': 'poly'}
# 0.655 (+/-0.160) for {'C': 100, 'kernel': 'sigmoid'}
# 0.836 (+/-0.130) for {'C': 1000, 'kernel': 'linear'}
# 0.560 (+/-0.086) for {'C': 1000, 'kernel': 'poly'}
# 0.655 (+/-0.160) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 700 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.681 (+/-0.160) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.681 (+/-0.160) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.681 (+/-0.160) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.681 (+/-0.160) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.681 (+/-0.160) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.681 (+/-0.160) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.681 (+/-0.160) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.681 (+/-0.160) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.681 (+/-0.160) for {'C': 1, 'kernel': 'linear'}
# 0.543 (+/-0.070) for {'C': 1, 'kernel': 'poly'}
# 0.681 (+/-0.160) for {'C': 1, 'kernel': 'sigmoid'}
# 0.681 (+/-0.160) for {'C': 10, 'kernel': 'linear'}
# 0.543 (+/-0.070) for {'C': 10, 'kernel': 'poly'}
# 0.681 (+/-0.160) for {'C': 10, 'kernel': 'sigmoid'}
# 0.750 (+/-0.151) for {'C': 100, 'kernel': 'linear'}
# 0.543 (+/-0.070) for {'C': 100, 'kernel': 'poly'}
# 0.681 (+/-0.160) for {'C': 100, 'kernel': 'sigmoid'}
# 0.853 (+/-0.137) for {'C': 1000, 'kernel': 'linear'}
# 0.543 (+/-0.070) for {'C': 1000, 'kernel': 'poly'}
# 0.681 (+/-0.160) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 800 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.655 (+/-0.157) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.157) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.157) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.157) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.157) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.157) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.157) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.655 (+/-0.157) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.655 (+/-0.157) for {'C': 1, 'kernel': 'linear'}
# 0.543 (+/-0.070) for {'C': 1, 'kernel': 'poly'}
# 0.655 (+/-0.157) for {'C': 1, 'kernel': 'sigmoid'}
# 0.655 (+/-0.157) for {'C': 10, 'kernel': 'linear'}
# 0.543 (+/-0.070) for {'C': 10, 'kernel': 'poly'}
# 0.655 (+/-0.157) for {'C': 10, 'kernel': 'sigmoid'}
# 0.767 (+/-0.164) for {'C': 100, 'kernel': 'linear'}
# 0.543 (+/-0.070) for {'C': 100, 'kernel': 'poly'}
# 0.655 (+/-0.157) for {'C': 100, 'kernel': 'sigmoid'}
# 0.828 (+/-0.143) for {'C': 1000, 'kernel': 'linear'}
# 0.543 (+/-0.070) for {'C': 1000, 'kernel': 'poly'}
# 0.655 (+/-0.157) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 900 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.724 (+/-0.156) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.724 (+/-0.156) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.724 (+/-0.156) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.724 (+/-0.156) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.724 (+/-0.156) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.724 (+/-0.156) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.724 (+/-0.156) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.724 (+/-0.156) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.724 (+/-0.156) for {'C': 1, 'kernel': 'linear'}
# 0.534 (+/-0.089) for {'C': 1, 'kernel': 'poly'}
# 0.724 (+/-0.156) for {'C': 1, 'kernel': 'sigmoid'}
# 0.733 (+/-0.150) for {'C': 10, 'kernel': 'linear'}
# 0.534 (+/-0.089) for {'C': 10, 'kernel': 'poly'}
# 0.724 (+/-0.156) for {'C': 10, 'kernel': 'sigmoid'}
# 0.784 (+/-0.154) for {'C': 100, 'kernel': 'linear'}
# 0.534 (+/-0.089) for {'C': 100, 'kernel': 'poly'}
# 0.724 (+/-0.156) for {'C': 100, 'kernel': 'sigmoid'}
# 0.793 (+/-0.151) for {'C': 1000, 'kernel': 'linear'}
# 0.534 (+/-0.089) for {'C': 1000, 'kernel': 'poly'}
# 0.724 (+/-0.156) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 1000 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.690 (+/-0.157) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.681 (+/-0.146) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.690 (+/-0.157) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.681 (+/-0.146) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.690 (+/-0.157) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.681 (+/-0.146) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.690 (+/-0.157) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.681 (+/-0.146) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.690 (+/-0.157) for {'C': 1, 'kernel': 'linear'}
# 0.534 (+/-0.089) for {'C': 1, 'kernel': 'poly'}
# 0.690 (+/-0.157) for {'C': 1, 'kernel': 'sigmoid'}
# 0.698 (+/-0.153) for {'C': 10, 'kernel': 'linear'}
# 0.534 (+/-0.089) for {'C': 10, 'kernel': 'poly'}
# 0.690 (+/-0.157) for {'C': 10, 'kernel': 'sigmoid'}
# 0.776 (+/-0.145) for {'C': 100, 'kernel': 'linear'}
# 0.534 (+/-0.089) for {'C': 100, 'kernel': 'poly'}
# 0.690 (+/-0.157) for {'C': 100, 'kernel': 'sigmoid'}
# 0.819 (+/-0.140) for {'C': 1000, 'kernel': 'linear'}
# 0.534 (+/-0.089) for {'C': 1000, 'kernel': 'poly'}
# 0.690 (+/-0.157) for {'C': 1000, 'kernel': 'sigmoid'}
# [{'k': None, 'mean': 0.7844827586206896}, {'k': 100, 'mean': 0.8620689655172413}, {'k': 200, 'mean': 0.853448275862069}, {'k': 300, 'mean': 0.8793103448275862}, {'k': 400, 'mean': 0.853448275862069}, {'k': 500, 'mean': 0.8362068965517241}, {'k': 600, 'mean': 0.8362068965517241}, {'k': 700, 'mean': 0.853448275862069}, {'k': 800, 'mean': 0.8275862068965517}, {'k': 900, 'mean': 0.7931034482758621}, {'k': 1000, 'mean': 0.8189655172413793}]
# Search for 14-28
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: All features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.644 (+/-0.146) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 1, 'kernel': 'linear'}
# 0.514 (+/-0.046) for {'C': 1, 'kernel': 'poly'}
# 0.644 (+/-0.146) for {'C': 1, 'kernel': 'sigmoid'}
# 0.733 (+/-0.153) for {'C': 10, 'kernel': 'linear'}
# 0.514 (+/-0.046) for {'C': 10, 'kernel': 'poly'}
# 0.644 (+/-0.146) for {'C': 10, 'kernel': 'sigmoid'}
# 0.788 (+/-0.098) for {'C': 100, 'kernel': 'linear'}
# 0.514 (+/-0.046) for {'C': 100, 'kernel': 'poly'}
# 0.644 (+/-0.146) for {'C': 100, 'kernel': 'sigmoid'}
# 0.753 (+/-0.141) for {'C': 1000, 'kernel': 'linear'}
# 0.514 (+/-0.046) for {'C': 1000, 'kernel': 'poly'}
# 0.644 (+/-0.146) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 100 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.658 (+/-0.141) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.664 (+/-0.145) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.658 (+/-0.141) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.664 (+/-0.145) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.658 (+/-0.141) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.664 (+/-0.145) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.658 (+/-0.141) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.664 (+/-0.145) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.658 (+/-0.141) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.048) for {'C': 1, 'kernel': 'poly'}
# 0.658 (+/-0.141) for {'C': 1, 'kernel': 'sigmoid'}
# 0.671 (+/-0.149) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.048) for {'C': 10, 'kernel': 'poly'}
# 0.658 (+/-0.141) for {'C': 10, 'kernel': 'sigmoid'}
# 0.822 (+/-0.113) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.048) for {'C': 100, 'kernel': 'poly'}
# 0.658 (+/-0.141) for {'C': 100, 'kernel': 'sigmoid'}
# 0.822 (+/-0.089) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.048) for {'C': 1000, 'kernel': 'poly'}
# 0.671 (+/-0.149) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 200 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.678 (+/-0.137) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.678 (+/-0.137) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.678 (+/-0.137) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.678 (+/-0.137) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.678 (+/-0.137) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.678 (+/-0.137) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.678 (+/-0.137) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.678 (+/-0.137) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.678 (+/-0.137) for {'C': 1, 'kernel': 'linear'}
# 0.507 (+/-0.058) for {'C': 1, 'kernel': 'poly'}
# 0.678 (+/-0.137) for {'C': 1, 'kernel': 'sigmoid'}
# 0.699 (+/-0.154) for {'C': 10, 'kernel': 'linear'}
# 0.507 (+/-0.058) for {'C': 10, 'kernel': 'poly'}
# 0.678 (+/-0.137) for {'C': 10, 'kernel': 'sigmoid'}
# 0.795 (+/-0.105) for {'C': 100, 'kernel': 'linear'}
# 0.507 (+/-0.058) for {'C': 100, 'kernel': 'poly'}
# 0.678 (+/-0.137) for {'C': 100, 'kernel': 'sigmoid'}
# 0.822 (+/-0.091) for {'C': 1000, 'kernel': 'linear'}
# 0.507 (+/-0.058) for {'C': 1000, 'kernel': 'poly'}
# 0.678 (+/-0.137) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 300 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.705 (+/-0.132) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.705 (+/-0.132) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.705 (+/-0.132) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.705 (+/-0.132) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.705 (+/-0.132) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.705 (+/-0.132) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.705 (+/-0.132) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.705 (+/-0.132) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.705 (+/-0.132) for {'C': 1, 'kernel': 'linear'}
# 0.521 (+/-0.066) for {'C': 1, 'kernel': 'poly'}
# 0.705 (+/-0.132) for {'C': 1, 'kernel': 'sigmoid'}
# 0.699 (+/-0.138) for {'C': 10, 'kernel': 'linear'}
# 0.521 (+/-0.066) for {'C': 10, 'kernel': 'poly'}
# 0.705 (+/-0.132) for {'C': 10, 'kernel': 'sigmoid'}
# 0.822 (+/-0.102) for {'C': 100, 'kernel': 'linear'}
# 0.521 (+/-0.066) for {'C': 100, 'kernel': 'poly'}
# 0.705 (+/-0.132) for {'C': 100, 'kernel': 'sigmoid'}
# 0.829 (+/-0.083) for {'C': 1000, 'kernel': 'linear'}
# 0.521 (+/-0.066) for {'C': 1000, 'kernel': 'poly'}
# 0.705 (+/-0.132) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 400 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.753 (+/-0.126) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.747 (+/-0.135) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.753 (+/-0.126) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.747 (+/-0.135) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.753 (+/-0.126) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.747 (+/-0.135) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.753 (+/-0.126) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.747 (+/-0.135) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.753 (+/-0.126) for {'C': 1, 'kernel': 'linear'}
# 0.555 (+/-0.125) for {'C': 1, 'kernel': 'poly'}
# 0.753 (+/-0.126) for {'C': 1, 'kernel': 'sigmoid'}
# 0.671 (+/-0.115) for {'C': 10, 'kernel': 'linear'}
# 0.555 (+/-0.125) for {'C': 10, 'kernel': 'poly'}
# 0.753 (+/-0.126) for {'C': 10, 'kernel': 'sigmoid'}
# 0.822 (+/-0.113) for {'C': 100, 'kernel': 'linear'}
# 0.555 (+/-0.125) for {'C': 100, 'kernel': 'poly'}
# 0.753 (+/-0.126) for {'C': 100, 'kernel': 'sigmoid'}
# 0.781 (+/-0.099) for {'C': 1000, 'kernel': 'linear'}
# 0.555 (+/-0.125) for {'C': 1000, 'kernel': 'poly'}
# 0.753 (+/-0.126) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 500 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.767 (+/-0.146) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.767 (+/-0.146) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.767 (+/-0.146) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.767 (+/-0.146) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.767 (+/-0.146) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.767 (+/-0.146) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.767 (+/-0.146) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.767 (+/-0.146) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.767 (+/-0.146) for {'C': 1, 'kernel': 'linear'}
# 0.507 (+/-0.058) for {'C': 1, 'kernel': 'poly'}
# 0.767 (+/-0.146) for {'C': 1, 'kernel': 'sigmoid'}
# 0.712 (+/-0.117) for {'C': 10, 'kernel': 'linear'}
# 0.507 (+/-0.058) for {'C': 10, 'kernel': 'poly'}
# 0.767 (+/-0.146) for {'C': 10, 'kernel': 'sigmoid'}
# 0.815 (+/-0.116) for {'C': 100, 'kernel': 'linear'}
# 0.507 (+/-0.058) for {'C': 100, 'kernel': 'poly'}
# 0.767 (+/-0.146) for {'C': 100, 'kernel': 'sigmoid'}
# 0.781 (+/-0.111) for {'C': 1000, 'kernel': 'linear'}
# 0.507 (+/-0.058) for {'C': 1000, 'kernel': 'poly'}
# 0.767 (+/-0.146) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 600 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.733 (+/-0.090) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.090) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.090) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.090) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.090) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.090) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.090) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.733 (+/-0.090) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.733 (+/-0.090) for {'C': 1, 'kernel': 'linear'}
# 0.541 (+/-0.098) for {'C': 1, 'kernel': 'poly'}
# 0.733 (+/-0.090) for {'C': 1, 'kernel': 'sigmoid'}
# 0.740 (+/-0.105) for {'C': 10, 'kernel': 'linear'}
# 0.541 (+/-0.098) for {'C': 10, 'kernel': 'poly'}
# 0.733 (+/-0.090) for {'C': 10, 'kernel': 'sigmoid'}
# 0.767 (+/-0.118) for {'C': 100, 'kernel': 'linear'}
# 0.541 (+/-0.098) for {'C': 100, 'kernel': 'poly'}
# 0.733 (+/-0.090) for {'C': 100, 'kernel': 'sigmoid'}
# 0.719 (+/-0.123) for {'C': 1000, 'kernel': 'linear'}
# 0.541 (+/-0.098) for {'C': 1000, 'kernel': 'poly'}
# 0.733 (+/-0.090) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 700 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.719 (+/-0.093) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.719 (+/-0.093) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.719 (+/-0.093) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.719 (+/-0.093) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.719 (+/-0.093) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.719 (+/-0.093) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.719 (+/-0.093) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.719 (+/-0.093) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.719 (+/-0.093) for {'C': 1, 'kernel': 'linear'}
# 0.514 (+/-0.025) for {'C': 1, 'kernel': 'poly'}
# 0.719 (+/-0.093) for {'C': 1, 'kernel': 'sigmoid'}
# 0.747 (+/-0.103) for {'C': 10, 'kernel': 'linear'}
# 0.514 (+/-0.025) for {'C': 10, 'kernel': 'poly'}
# 0.719 (+/-0.093) for {'C': 10, 'kernel': 'sigmoid'}
# 0.781 (+/-0.106) for {'C': 100, 'kernel': 'linear'}
# 0.514 (+/-0.025) for {'C': 100, 'kernel': 'poly'}
# 0.719 (+/-0.093) for {'C': 100, 'kernel': 'sigmoid'}
# 0.747 (+/-0.142) for {'C': 1000, 'kernel': 'linear'}
# 0.514 (+/-0.025) for {'C': 1000, 'kernel': 'poly'}
# 0.719 (+/-0.093) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 800 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.719 (+/-0.115) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.719 (+/-0.115) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.719 (+/-0.115) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.719 (+/-0.115) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.719 (+/-0.115) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.719 (+/-0.115) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.719 (+/-0.115) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.719 (+/-0.115) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.719 (+/-0.115) for {'C': 1, 'kernel': 'linear'}
# 0.541 (+/-0.098) for {'C': 1, 'kernel': 'poly'}
# 0.719 (+/-0.115) for {'C': 1, 'kernel': 'sigmoid'}
# 0.740 (+/-0.105) for {'C': 10, 'kernel': 'linear'}
# 0.541 (+/-0.098) for {'C': 10, 'kernel': 'poly'}
# 0.719 (+/-0.115) for {'C': 10, 'kernel': 'sigmoid'}
# 0.795 (+/-0.131) for {'C': 100, 'kernel': 'linear'}
# 0.541 (+/-0.098) for {'C': 100, 'kernel': 'poly'}
# 0.719 (+/-0.115) for {'C': 100, 'kernel': 'sigmoid'}
# 0.760 (+/-0.103) for {'C': 1000, 'kernel': 'linear'}
# 0.541 (+/-0.098) for {'C': 1000, 'kernel': 'poly'}
# 0.719 (+/-0.115) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 900 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.630 (+/-0.124) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.630 (+/-0.124) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.630 (+/-0.124) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.630 (+/-0.124) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.630 (+/-0.124) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.630 (+/-0.124) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.630 (+/-0.124) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.630 (+/-0.124) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.630 (+/-0.124) for {'C': 1, 'kernel': 'linear'}
# 0.507 (+/-0.033) for {'C': 1, 'kernel': 'poly'}
# 0.630 (+/-0.124) for {'C': 1, 'kernel': 'sigmoid'}
# 0.705 (+/-0.132) for {'C': 10, 'kernel': 'linear'}
# 0.507 (+/-0.033) for {'C': 10, 'kernel': 'poly'}
# 0.630 (+/-0.124) for {'C': 10, 'kernel': 'sigmoid'}
# 0.781 (+/-0.121) for {'C': 100, 'kernel': 'linear'}
# 0.507 (+/-0.033) for {'C': 100, 'kernel': 'poly'}
# 0.630 (+/-0.124) for {'C': 100, 'kernel': 'sigmoid'}
# 0.801 (+/-0.093) for {'C': 1000, 'kernel': 'linear'}
# 0.507 (+/-0.033) for {'C': 1000, 'kernel': 'poly'}
# 0.630 (+/-0.124) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 1000 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.644 (+/-0.146) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.644 (+/-0.146) for {'C': 1, 'kernel': 'linear'}
# 0.514 (+/-0.046) for {'C': 1, 'kernel': 'poly'}
# 0.644 (+/-0.146) for {'C': 1, 'kernel': 'sigmoid'}
# 0.719 (+/-0.127) for {'C': 10, 'kernel': 'linear'}
# 0.514 (+/-0.046) for {'C': 10, 'kernel': 'poly'}
# 0.644 (+/-0.146) for {'C': 10, 'kernel': 'sigmoid'}
# 0.760 (+/-0.093) for {'C': 100, 'kernel': 'linear'}
# 0.514 (+/-0.046) for {'C': 100, 'kernel': 'poly'}
# 0.644 (+/-0.146) for {'C': 100, 'kernel': 'sigmoid'}
# 0.740 (+/-0.125) for {'C': 1000, 'kernel': 'linear'}
# 0.514 (+/-0.046) for {'C': 1000, 'kernel': 'poly'}
# 0.644 (+/-0.146) for {'C': 1000, 'kernel': 'sigmoid'}
# [{'k': None, 'mean': 0.7876712328767124}, {'k': 100, 'mean': 0.821917808219178}, {'k': 200, 'mean': 0.821917808219178}, {'k': 300, 'mean': 0.8287671232876712}, {'k': 400, 'mean': 0.821917808219178}, {'k': 500, 'mean': 0.815068493150685}, {'k': 600, 'mean': 0.7671232876712328}, {'k': 700, 'mean': 0.7808219178082192}, {'k': 800, 'mean': 0.7945205479452054}, {'k': 900, 'mean': 0.8013698630136986}, {'k': 1000, 'mean': 0.7602739726027398}]
# Search for 21-28
# # Tuning hyper-parameters for accuracy
# Best parameters set found on development set: All features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.636 (+/-0.180) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.636 (+/-0.180) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.636 (+/-0.180) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.636 (+/-0.180) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.636 (+/-0.180) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.636 (+/-0.180) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.636 (+/-0.180) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.636 (+/-0.180) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.636 (+/-0.180) for {'C': 1, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 1, 'kernel': 'poly'}
# 0.636 (+/-0.180) for {'C': 1, 'kernel': 'sigmoid'}
# 0.693 (+/-0.167) for {'C': 10, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 10, 'kernel': 'poly'}
# 0.636 (+/-0.180) for {'C': 10, 'kernel': 'sigmoid'}
# 0.693 (+/-0.130) for {'C': 100, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 100, 'kernel': 'poly'}
# 0.636 (+/-0.180) for {'C': 100, 'kernel': 'sigmoid'}
# 0.739 (+/-0.152) for {'C': 1000, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 1000, 'kernel': 'poly'}
# 0.636 (+/-0.180) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 100 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.534 (+/-0.086) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.534 (+/-0.086) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.534 (+/-0.086) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.534 (+/-0.086) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.534 (+/-0.086) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.534 (+/-0.086) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.534 (+/-0.086) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.534 (+/-0.086) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.534 (+/-0.086) for {'C': 1, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 1, 'kernel': 'poly'}
# 0.534 (+/-0.086) for {'C': 1, 'kernel': 'sigmoid'}
# 0.534 (+/-0.086) for {'C': 10, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 10, 'kernel': 'poly'}
# 0.534 (+/-0.086) for {'C': 10, 'kernel': 'sigmoid'}
# 0.716 (+/-0.137) for {'C': 100, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 100, 'kernel': 'poly'}
# 0.534 (+/-0.086) for {'C': 100, 'kernel': 'sigmoid'}
# 0.807 (+/-0.134) for {'C': 1000, 'kernel': 'linear'}
# 0.511 (+/-0.052) for {'C': 1000, 'kernel': 'poly'}
# 0.534 (+/-0.086) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 200 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.534 (+/-0.114) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.534 (+/-0.114) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.534 (+/-0.114) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.534 (+/-0.114) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.534 (+/-0.114) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.534 (+/-0.114) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.534 (+/-0.114) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.534 (+/-0.114) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.534 (+/-0.114) for {'C': 1, 'kernel': 'linear'}
# 0.523 (+/-0.072) for {'C': 1, 'kernel': 'poly'}
# 0.534 (+/-0.114) for {'C': 1, 'kernel': 'sigmoid'}
# 0.534 (+/-0.114) for {'C': 10, 'kernel': 'linear'}
# 0.523 (+/-0.072) for {'C': 10, 'kernel': 'poly'}
# 0.534 (+/-0.114) for {'C': 10, 'kernel': 'sigmoid'}
# 0.716 (+/-0.157) for {'C': 100, 'kernel': 'linear'}
# 0.523 (+/-0.072) for {'C': 100, 'kernel': 'poly'}
# ...
# 0.534 (+/-0.121) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.534 (+/-0.121) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.534 (+/-0.121) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.534 (+/-0.121) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.050) for {'C': 1, 'kernel': 'poly'}
# 0.534 (+/-0.121) for {'C': 1, 'kernel': 'sigmoid'}
# 0.610 (+/-0.152) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.050) for {'C': 10, 'kernel': 'poly'}
# 0.534 (+/-0.121) for {'C': 10, 'kernel': 'sigmoid'}
# 0.720 (+/-0.124) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.050) for {'C': 100, 'kernel': 'poly'}
# 0.534 (+/-0.121) for {'C': 100, 'kernel': 'sigmoid'}
# 0.627 (+/-0.155) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.050) for {'C': 1000, 'kernel': 'poly'}
# 0.534 (+/-0.121) for {'C': 1000, 'kernel': 'sigmoid'}
# [{'k': None, 'mean': 0.6440677966101694}, {'k': 100, 'mean': 0.6864406779661016}, {'k': 200, 'mean': 0.6949152542372882}, {'k': 300, 'mean': 0.7457627118644068}, {'k': 400, 'mean': 0.711864406779661}, {'k': 500, 'mean': 0.7203389830508474}, {'k': 600, 'mean': 0.7372881355932204}, {'k': 700, 'mean': 0.7288135593220338}, {'k': 800, 'mean': 0.7372881355932204}, {'k': 900, 'mean': 0.7288135593220338}, {'k': 1000, 'mean': 0.7203389830508474}]
# Search for 28-35
# # Tuning hyper-parameters for accuracy
# Best parameters set found on development set: All features
#
# {'C': 10, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.550 (+/-0.208) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.208) for {'C': 1, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'poly'}
# 0.550 (+/-0.208) for {'C': 1, 'kernel': 'sigmoid'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'poly'}
# 0.550 (+/-0.208) for {'C': 10, 'kernel': 'sigmoid'}
# 0.667 (+/-0.175) for {'C': 100, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 100, 'kernel': 'poly'}
# 0.550 (+/-0.208) for {'C': 100, 'kernel': 'sigmoid'}
# 0.583 (+/-0.197) for {'C': 1000, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1000, 'kernel': 'poly'}
# 0.550 (+/-0.208) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 100 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.533 (+/-0.085) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'sigmoid'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'sigmoid'}
# 0.533 (+/-0.085) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.533 (+/-0.085) for {'C': 100, 'kernel': 'sigmoid'}
# 0.650 (+/-0.220) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.533 (+/-0.085) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 200 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.550 (+/-0.100) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.533 (+/-0.085) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.550 (+/-0.100) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.550 (+/-0.100) for {'C': 1, 'kernel': 'sigmoid'}
# 0.550 (+/-0.100) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.550 (+/-0.100) for {'C': 10, 'kernel': 'sigmoid'}
# 0.550 (+/-0.100) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.550 (+/-0.100) for {'C': 100, 'kernel': 'sigmoid'}
# 0.683 (+/-0.213) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.550 (+/-0.100) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 300 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'sigmoid'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'sigmoid'}
# 0.633 (+/-0.201) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 100, 'kernel': 'sigmoid'}
# 0.700 (+/-0.208) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 400 features
#
# {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'sigmoid'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 10, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'sigmoid'}
# 0.667 (+/-0.197) for {'C': 100, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 100, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 100, 'kernel': 'sigmoid'}
# 0.667 (+/-0.175) for {'C': 1000, 'kernel': 'linear'}
# 0.533 (+/-0.085) for {'C': 1000, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 500 features
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.650 (+/-0.153) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.650 (+/-0.153) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.650 (+/-0.153) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.650 (+/-0.153) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.650 (+/-0.153) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.650 (+/-0.153) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.650 (+/-0.153) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.650 (+/-0.153) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.650 (+/-0.153) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.650 (+/-0.153) for {'C': 1, 'kernel': 'sigmoid'}
# 0.650 (+/-0.153) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.650 (+/-0.153) for {'C': 10, 'kernel': 'sigmoid'}
# 0.667 (+/-0.149) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.650 (+/-0.153) for {'C': 100, 'kernel': 'sigmoid'}
# 0.683 (+/-0.170) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.650 (+/-0.153) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 600 features
#
# {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.717 (+/-0.221) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.717 (+/-0.221) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.717 (+/-0.221) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.717 (+/-0.221) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.700 (+/-0.208) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.717 (+/-0.221) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.717 (+/-0.221) for {'C': 1, 'kernel': 'sigmoid'}
# 0.717 (+/-0.221) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.717 (+/-0.221) for {'C': 10, 'kernel': 'sigmoid'}
# 0.650 (+/-0.255) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.717 (+/-0.221) for {'C': 100, 'kernel': 'sigmoid'}
# 0.667 (+/-0.149) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.717 (+/-0.221) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 700 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'sigmoid'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 10, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'sigmoid'}
# 0.633 (+/-0.180) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 100, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 100, 'kernel': 'sigmoid'}
# 0.633 (+/-0.155) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.062) for {'C': 1000, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 800 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'linear'}
# 0.550 (+/-0.135) for {'C': 1, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1, 'kernel': 'sigmoid'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'linear'}
# 0.550 (+/-0.135) for {'C': 10, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 10, 'kernel': 'sigmoid'}
# 0.650 (+/-0.153) for {'C': 100, 'kernel': 'linear'}
# 0.550 (+/-0.135) for {'C': 100, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 100, 'kernel': 'sigmoid'}
# 0.517 (+/-0.193) for {'C': 1000, 'kernel': 'linear'}
# 0.550 (+/-0.135) for {'C': 1000, 'kernel': 'poly'}
# 0.617 (+/-0.155) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 900 features
#
# {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'linear'}
# 0.517 (+/-0.111) for {'C': 1, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1, 'kernel': 'sigmoid'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'linear'}
# 0.517 (+/-0.111) for {'C': 10, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 10, 'kernel': 'sigmoid'}
# 0.633 (+/-0.221) for {'C': 100, 'kernel': 'linear'}
# 0.517 (+/-0.111) for {'C': 100, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 100, 'kernel': 'sigmoid'}
# 0.600 (+/-0.200) for {'C': 1000, 'kernel': 'linear'}
# 0.517 (+/-0.111) for {'C': 1000, 'kernel': 'poly'}
# 0.667 (+/-0.217) for {'C': 1000, 'kernel': 'sigmoid'}
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set: 1000 features
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.567 (+/-0.193) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.567 (+/-0.193) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.193) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.567 (+/-0.193) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.193) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.567 (+/-0.193) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.193) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.567 (+/-0.193) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.567 (+/-0.193) for {'C': 1, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1, 'kernel': 'poly'}
# 0.567 (+/-0.193) for {'C': 1, 'kernel': 'sigmoid'}
# 0.567 (+/-0.193) for {'C': 10, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 10, 'kernel': 'poly'}
# 0.567 (+/-0.193) for {'C': 10, 'kernel': 'sigmoid'}
# 0.633 (+/-0.180) for {'C': 100, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 100, 'kernel': 'poly'}
# 0.567 (+/-0.193) for {'C': 100, 'kernel': 'sigmoid'}
# 0.617 (+/-0.221) for {'C': 1000, 'kernel': 'linear'}
# 0.500 (+/-0.000) for {'C': 1000, 'kernel': 'poly'}
# 0.567 (+/-0.193) for {'C': 1000, 'kernel': 'sigmoid'}
# [{'k': None, 'mean': 0.6666666666666666}, {'k': 100, 'mean': 0.65}, {'k': 200, 'mean': 0.6833333333333333}, {'k': 300, 'mean': 0.7}, {'k': 400, 'mean': 0.6666666666666666}, {'k': 500, 'mean': 0.6833333333333333}, {'k': 600, 'mean': 0.7166666666666667}, {'k': 700, 'mean': 0.6333333333333333}, {'k': 800, 'mean': 0.65}, {'k': 900, 'mean': 0.6666666666666666}, {'k': 1000, 'mean': 0.6333333333333333}]
